# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyasarican/PythonMachineLearning/blob/main/R2_AdjustedR2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - R2 yönteminde sonuç 1'e yaklaştıkça başarı oranı artar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Örneğin elimizde bir doğrusal regresyon modeli var.(boydan yaş bulmak)
# - Bu modeli çok boyutlu hale getiriğ(cinsiyet özelliğini eklemek) başarısını ölçerken R2 yöntemi düzgün çalışmaz.
# - Bizim aslında bakmak istediğimiz şey yeni özellik eklenip R2'yi hesapladığımızda sonuç azalıyorsa yeni özellikle daha başarısız model, artıyorsa daha başarılı bi model kurmuş olmamız.
# - Ama R2 asla azalmaz. Ya sabit kalır ya artar.
# ---
# - Bunun önüne geçmek için Adjusted R2 yöntemi kullanılır.
# - n:eleman sayısı
# - p:değişken sayısı
