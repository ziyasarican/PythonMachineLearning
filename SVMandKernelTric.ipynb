# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyasarican/PythonMachineLearning/blob/main/SVMandKernelTric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - SVM ve Kernel Trick

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# - Ayrılamayan verilerde boyut arttırılır.
# - 2 boyuttan 3 boyuta çıkarmak gibi.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
